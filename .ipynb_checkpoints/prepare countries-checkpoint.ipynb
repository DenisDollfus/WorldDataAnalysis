# %%
import pandas as pd
from pandas import json_normalize
import json

# %% [markdown]
# Read countries

# %%
with open('data/country_list_2022.json','r') as f:
    data = json.loads(f.read())
    
countries = json_normalize(data, record_path =['data'])
countries.top()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-294456baf229> in <module>()
#       3
#       4 countries = json_normalize(data, record_path =['data'])
# ----> 5 countries.top()
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'top'

# %%
countries
# Out:
#                                    source  \
# 0    https://datahub.io/core/country-list
# 1    https://datahub.io/core/country-list
# 2    https://datahub.io/core/country-list
# 3    https://datahub.io/core/country-list
# 4    https://datahub.io/core/country-list
# 5    https://datahub.io/core/country-list
# 6    https://datahub.io/core/country-list
# 7    https://datahub.io/core/country-list
# 8    https://datahub.io/core/country-list
# 9    https://datahub.io/core/country-list
# 10   https://datahub.io/core/country-list
# 11   https://datahub.io/core/country-list
# 12   https://datahub.io/core/country-list
# 13   https://datahub.io/core/country-list
# 14   https://datahub.io/core/country-list
# 15   https://datahub.io/core/country-list
# 16   https://datahub.io/core/country-list
# 17   https://datahub.io/core/country-list
# 18   https://datahub.io/core/country-list
# 19   https://datahub.io/core/country-list
# 20   https://datahub.io/core/country-list
# ...
